# %%
import matplotlib.pyplot as plt

# %%
#  1创建画布(容器层)
plt.figure(figsize=(10, 10))

# %%
# 2 绘制折线图(图像层)
import random
plt.plot([1,2,3,4,5,6,7], random.shuffle([i for i in range(10, 17)]))
# 3 显示图像
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-93c6b8b591f8> in <module>
#       1 # 2 绘制折线图(图像层)
#       2 import random
# ----> 3 plt.plot([1,2,3,4,5,6,7], random.shuffle([i for i in range(10, 17)]))
#       4 # 3 显示图像
#       5 plt.show()
#
# F:\anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# F:\anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
# ...

# %%
random.shuffle([i for i in range(10, 17)])

# %%
random.shuffle?

# %%
s = [i for i in range(10, 17)]
random.shuffle(s)
plt.plot([i for i in range(1,8)], s)
plt.show()

# %%
random.shuffle(s)
plt.plot([i for i in range(1,8)], s)
plt.show()
